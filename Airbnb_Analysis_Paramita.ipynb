# %% [markdown]
# <font size='7px'><font color='#9138cb'>***Airbnb Bookings Analysis***

# %% [markdown]
# # Project type - **Explotory Data Analysis**

# %% [markdown]
# # Project Summary : -

# %% [markdown]
# **🌐 What is Airbnb:-
# Airbnb is an American company operating an online marketplace for short-and-long-term homestays, experiences and services in various countries and regions. It acts as a broker and charges a commission from each booking. Airbnb was founded in 2008 by Brian Chesky, Nathan Blecharczyk, and Joe Gebbia. It is the best-known company for short-term housing rentals.**

# %% [markdown]
# **✨ How Airbnb Has Transformed Travel:-
# Airbnb has revolutionized the way people travel and experience new places by providing a unique and personalized alternative to traditional hotel stays. By connecting hosts who have extra space in their homes or apartments with travelers looking for a more authentic and local experience, Airbnb has created a thriving community of people from all over the world who are passionate about exploring new cultures and sharing their own.**

# %% [markdown]
# **🎯 Project Objective:-
# This project aims to explore and analyze a dataset of approximately 49,000 Airbnb listings in order to gain a better understanding of the factors that drive success on the platform. The dataset includes both categorical and numeric variables, such as the location of the listing, the type of property, the price, the number of reviews, and the amenities offered.**

# %% [markdown]
# **❓ Key Questions:-
# One of the key questions we can explore using this data is what sets successful hosts apart from those who may be struggling. By examining variables such as the number of bookings and reviews, the location of the listings, and the amenities offered, we can identify patterns and trends that may be correlated with higher levels of success.**

# %% [markdown]
# **🧼 Data Exploration and Cleaning:-
# This project involved exploring and cleaning a dataset to prepare it for analysis. The data exploration process involved identifying and understanding the characteristics of the data, such as the data types, missing values, and distributions of values. The data cleaning process involved identifying and addressing any issues or inconsistencies in the data, such as errors, missing values, or duplicate records and remove outliers.**

# %% [markdown]
# **✅ Clean and Prepared Data:- Through this process, we were able to identify and fix any issues with the data, and ensure that it was ready for further analysis. This is an important step in any data analysis project, as it allows us to work with high-quality data and avoid any potential biases or errors that could affect the results. The clean and prepared data can now be used to answer specific research.**

# %% [markdown]
# **🔍 Data Exploration and Pattern Detection:-
# Once the data has been cleaned and prepared, now begin exploring and summarizing it with describe the data and creating visualizations, and identifying patterns and trends in the data. in explore the data, may develop the relationships between different variables or the underlying causes of certain patterns or trends and other methods.**

# %% [markdown]
# **📊 Data Visualization:-
# using data visualization to explore and understand patterns in Airbnb data. We created various graphs and charts to visualize the data, and wrote observations and insights below each one to help us better understand the data and identify useful insights and patterns.**

# %% [markdown]
# # **Problem Statements -**

# %% [markdown]
# 1. Find Distribution of Airbnb Booking Price Range
# 2. Find Total Listings per Neighborhood Group
# 3. Find Average Price per Neighborhood Group and Neighborhood
# 4. Find Top Neighborhoods and Hosts by Listings
# 5. Find Active Hosts per Neighborhood Group
# 6. Find Counts of Each Room Type
# 7. Find Stay Requirement Counts by Minimum Nights
# 8. Find Total and Max Reviews per Neighborhood Group
# 9. Find Most Reviewed Room Type per Neighborhood Group
# 10. Find Best Location Listings for Travelers
# 11. Find Best Location Listings for Hosts
# 12. Find Price Variations Across Neighborhood Groups
# 13. Find Average Reviews Per Month by Room Type
# 14. Find Correlation Between Price and Reviews
# 15. Find Most Affordable Neighborhoods (Average Price < 100)
# 16. Find Listings with Zero Reviews
# 17. Find Distribution of Minimum Nights by Room Type
# 18. Find Top 10 Reviewed Listings
# 19. Find Price vs Reviews per Month by Neighborhood Group
# 20. Find Listings Count by Host Name (Top 10 Only)

# %% [markdown]
# # **1. LOAD DATA**

# %% [markdown]
# **Import** **Libraries**

# %%
# Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

#Import warnings are issued to alert developers to potential issues with their code,
# and it is important to address these warnings in order to avoid potential problems
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **use pandas to read csv**

# %%
df= pd.read_csv('Airbnb_Analysis.csv')

# %% [markdown]
# **Preview the data**

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# This dataset contains detailed information about Airbnb bookings in New York City, with approximately 49,000 observations and 16 features. Each row represents a unique listing, and the columns provide a variety of information including:
# - Listing ID, name, host details
# - Location data: neighborhood, latitude, longitude
# - Room type and pricing
# - Booking metrics: minimum nights, availability, reviews
#
# The data includes a mix of categorical and numerical variables, allowing :to explore patterns across different boroughs, room types, price ranges, host activity, and customer engagement.
# This dataset is valuable for:
# - 📈 Analyzing booking behavior and pricing trends
# - 🏙️ Understanding geographic preferences of guests
# - 🧑‍💼 Evaluating host performance and listing popularity
# - 🔍 Identifying factors that influence review frequency and availability
# By performing Exploratory Data Analysis.

# %% [markdown]
# # **2. Inspection**

# %% [markdown]
# **Dimensions** **of** **Data**

# %%
df.shape
# Out:
# (48895, 16)

# %% [markdown]
# **Data types and non-null counts**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# **Basic stats**

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# **Feature Description**

# %% [markdown]
# *   **name:** The title of the listing—ranging from cozy corners to extravagant penthouses. It gives personality to each entry
#
#
# *   **host_id:** A  unique fingerprint for every Airbnb host. Think of it as their backstage pass into the platform’s listings universe.
#
#
# *   **host_name:** The real or displayed name of the host—who could be a world traveler, entrepreneur, or someone renting out their spare room.
# *   **neighbourhood_group:** A big-picture view of where the listing lives—Manhattan, Brooklyn, Queens, etc.—the borough breakdown of NYC charm.
#
# *   **neighbourhood:** Zoom in from borough to block: this is the specific community or district that adds unique flavor to each stay.
#
# *   **latitude:** The north-south coordinate placing each listing on the map. It helps you geolocate the apartment vibes.
#
# *   **longitude:** The east-west map coordinate—a tag in the digital landscape for pinpointing each listing’s place in the city maze.
# *   **room_type:** Is it a full apartment, a private room, or something more communal? This column defines how much space guests actually get.
#
# *   **price:** The cost per night—could be a shoestring budget deal or a baller’s dream pad. Your wallet will definitely notice this one
# *   **minimum_nights:** The minimum length of stay. Some spots require just one night, others demand a weeklong commitment.
#
#
# *   **number_of_reviews:** Feedback from past guests. High numbers can signal popularity, trustworthiness, or just great pancakes in the morning.
# *   **reviews_per_month:** A freshness indicator for listings—how active is this listing in getting consistent reviews month after month?
#
# *   **calculated_host_listings_count:**  How many listings a host actually manages. From one humble flat to dozens of Airbnb empires, this tells you who's scaling up.
# *   **availability_365:**  Out of the full calendar year, how often is this listing actually open for business? A number that shows host commitment and flexibility.

# %% [markdown]
# **Check for missing values**

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# # ***3. Data Cleaning***

# %% [markdown]
# **Drop duplicate rows**

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# **Replacing null values**

# %%
# name and host_name will replace by 'unknown'
df['name'].fillna('unknown', inplace = True)
df['host_name'].fillna('unknown', inplace = True)

# %%
# Replace NaN values in 'review_per_month' with 0
df['reviews_per_month'].fillna(0, inplace=True)

# %% [markdown]
# **Drop irrelevant columns**

# %%
# Drop last_review because it not be helpful unless we're doing time-series or review timing analysis.
df.drop(['last_review'], axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# # **4. UNIVARIATE ANALYSIS**

# %% [markdown]
# **Distribution of Prices**

# %%
sns.histplot(df['price'], bins=50, kde=True, color='green')
plt.title('Distribution of Airbnb Prices')
plt.xlabel('Price')
plt.show()

# %% [markdown]
# **Removing Outliers (Price IQR)**

# %%
def remove_outliers_iqr(group_df):
    Q1 = group_df['price'].quantile(0.25)
    Q3 = group_df['price'].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return group_df[(group_df['price'] >= lower_bound) & (group_df['price'] <= upper_bound)]

# Group-wise filtering and definition of df_filtered
df_filtered = df.groupby('room_type').apply(remove_outliers_iqr).reset_index(drop=True)

# %%
sns.histplot(df_filtered['price'], bins=50, kde=True, color='blue')
plt.title('Distribution of Airbnb Prices')
plt.xlabel('Price')
plt.show()

# %% [markdown]
# # **5. BIVARIATE ANALYSIS**

# %% [markdown]
# **Price vs Room Type**

# %%
sns.boxplot(data=df, x='room_type', y='price')
plt.title('Price by Room Type')
plt.show()

# %% [markdown]
# # **DATA VISUALIZATION**

# %% [markdown]
# **🏷️ Distribution of Airbnb Bookings Price Range**

# %%
sns.histplot(df_filtered['price'], bins=50, kde=True, color='green')
plt.title('Distribution of Airbnb Prices')
plt.xlabel('Price')
plt.show()

# %% [markdown]
# **Key Observation:-**
# - The majority of listings fall within the ₹0–₹150 price range, with a sharp peak near ₹50, suggesting that affordable options dominate the NYC Airbnb market.
# - As price increases beyond ₹150, the number of listings drops significantly, indicating that mid-range and luxury options are less frequent.
# - The KDE curve reinforces this trend, showing a steep concentration of values in the low-price region and a long, thin tail extending toward high-priced listings.

# %% [markdown]
# **🏘️ Total Listings per Neighborhood Group**

# %%
sns.countplot(data=df_filtered, x='neighbourhood_group', palette='pastel')
plt.title('Total Listings by Neighborhood Group')
plt.show()

# %% [markdown]
# **Key Insights:-**
# - Manhattan leads the pack with the highest number of listings, closely followed by Brooklyn. These two boroughs represent NYC’s tourism and accommodation hubs, offering a vibrant mix of culture, accessibility, and traveler interest.
# - Queens has a moderate presence, likely reflecting its residential nature and proximity to JFK and LaGuardia airports.
# - Bronx and Staten Island have significantly fewer listings, each falling well below 2,500. This suggests they are either underrepresented in Airbnb’s market or cater to a more localized or niche audience.

# %% [markdown]
# **💰 Average Price per Neighborhood Group and Neighborhood**

# %%
avg_price_group = df_filtered.groupby('neighbourhood_group')['price'].mean().sort_values()
avg_price_neigh = df_filtered.groupby('neighbourhood')['price'].mean().sort_values()

print("Average Price by Neighborhood Group:\n", avg_price_group)
print("\nAverage Price by Neighborhood:\n", avg_price_neigh)
# Out:
# Average Price by Neighborhood Group:
#  neighbourhood_group
# Bronx             77.596623
# Staten Island     87.461111
# Queens            88.605978
# Brooklyn         107.013622
# Manhattan        149.138377
# Name: price, dtype: float64
#
# Average Price by Neighborhood:
#  neighbourhood
# Bull's Head           47.333333
# Hunts Point           50.500000
# Tremont               51.545455
# Soundview             53.466667
# New Dorp              57.000000
#                         ...
# Flatiron District    205.483333
# NoHo                 218.620690
# Tribeca              232.810345
# Willowbrook          249.000000
# Neponsit             274.666667
# Name: price, Length: 218, dtype: float64

# %% [markdown]
# **🌟 Top Neighborhoods and Hosts by Listings**

# %%
top_neigh = df_filtered['neighbourhood'].value_counts().nlargest(10)
top_hosts = df_filtered['host_name'].value_counts().nlargest(10)

print("Top Neighborhoods by Listings:\n", top_neigh)
print("\nTop Hosts by Listings:\n", top_hosts)
# Out:
# Top Neighborhoods by Listings:
#  neighbourhood
# Williamsburg          3740
# Bedford-Stuyvesant    3615
# Harlem                2551
# Bushwick              2440
# Upper West Side       1779
# East Village          1695
# Hell's Kitchen        1682
# Upper East Side       1662
# Crown Heights         1522
# Midtown               1131
# Name: count, dtype: int64
#
# Top Hosts by Listings:
#  host_name
# Michael         381
# David           374
# John            277
# Sonder (NYC)    273
# Alex            254
# Sarah           217
# Blueground      217
# Daniel          214
# Maria           196
# Mike            184
# Name: count, dtype: int64

# %% [markdown]
# **👥 Active Hosts per Neighborhood Group**

# %%
active_hosts = df_filtered.groupby('neighbourhood_group')['host_name'].nunique().sort_values()
print("Active Hosts per Neighborhood Group:\n", active_hosts)
# Out:
# Active Hosts per Neighborhood Group:
#  neighbourhood_group
# Staten Island     210
# Bronx             643
# Queens           2386
# Manhattan        5548
# Brooklyn         5951
# Name: host_name, dtype: int64

# %% [markdown]
# **🛏️ Counts of Each Room Type**

# %%
sns.countplot(data=df_filtered, x='room_type', palette='Set3')
plt.title('Room Type Counts')
plt.show()

# %% [markdown]
# **Key Observation:-**
# - Entire home/apt dominates the dataset, indicating a strong preference among travelers for full-space privacy and autonomy.
# - Private rooms come in second, suggesting budget-conscious guests still value personal space without paying for an entire property.
# - Shared rooms are the least common, representing only a small fraction of listings—likely due to limited demand or regulatory restrictions.

# %% [markdown]
# **📆 Stay Requirement Counts by Minimum Nights**

# %%
sns.histplot(df_filtered['minimum_nights'], bins=30, color='brown')
plt.title('Minimum Nights Distribution (Outliers Removed)')
plt.xlabel('Minimum Nights')
plt.show()

# %% [markdown]
# **Key Takeaways:-**
# - The vast majority of listings require just 1 or 2 nights, showing that short-term stays are the norm and highly accessible for travelers.
# - Beyond 2 nights, the count rapidly declines—only a small number of listings require 3 or more nights.
# - The curve flattens around 6 nights and above, implying that long-stay requirements are rare and likely targeted toward niche travelers or specific housing policies.

# %% [markdown]
# **📝 Total and Max Reviews per Neighborhood**

# %%
total_reviews = df_filtered.groupby('neighbourhood_group')['number_of_reviews'].sum()
max_reviews = df_filtered.groupby('neighbourhood_group')['number_of_reviews'].max()

print("Total Reviews per Neighborhood Group:\n", total_reviews)
print("\nMaximum Reviews per Neighborhood Group:\n", max_reviews)
# Out:
# Total Reviews per Neighborhood Group:
#  neighbourhood_group
# Bronx             27748
# Brooklyn         455685
# Manhattan        397604
# Queens           151156
# Staten Island     11322
# Name: number_of_reviews, dtype: int64
#
# Maximum Reviews per Neighborhood Group:
#  neighbourhood_group
# Bronx            321
# Brooklyn         488
# Manhattan        607
# Queens           629
# Staten Island    333
# Name: number_of_reviews, dtype: int64

# %% [markdown]
# **🏠 Most Reviewed Room Type per Neighborhood Group**

# %%
room_reviews = df_filtered.groupby(['neighbourhood_group', 'room_type'])['reviews_per_month'].sum().unstack()
room_reviews.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Most Reviewed Room Type per Neighborhood Group')
plt.ylabel('Reviews per Month')
plt.show()

# %% [markdown]
# **Observation:-**
# - Manhattan tops the review activity, especially for Entire home/apt and Private room listings—this suggests it’s the hotspot for active and frequent guest engagement.
# - Brooklyn follows closely, reflecting its strong Airbnb presence and demand.
# - Queens has moderate review activity, mostly leaning toward Private rooms.
# - The Bronx and Staten Island lag significantly in monthly review volume, likely due to fewer listings and lower tourist traffic.
# - Across all boroughs, Shared rooms receive the least attention—indicating limited interest in communal stays.

# %% [markdown]
# **✈️ Best Location Listings for Travelers**

# %%
best_travel = df_filtered[(df_filtered['price'] < 100) & (df_filtered['number_of_reviews'] > 50)]
print("Best Listings for Travelers:\n")
print(best_travel[['name', 'neighbourhood_group', 'price', 'number_of_reviews']].head())
# Out:
# Best Listings for Travelers:
#
#                                                 name neighbourhood_group  \
# 1                    Cozy Entire Floor of Brownstone            Brooklyn
# 9    Hip Historic Brownstone Apartment with Backyard            Brooklyn
# 15                         Cute apt in artist's home            Brooklyn
# 77                     CENTRAL PARK LOFT all for YOU           Manhattan
# 120                      The gem of the East Village           Manhattan
#
#      price  number_of_reviews
# 1       89                270
# 9       99                 53
# 15      85                231
# 77      99                234
# 120     99                127

# %% [markdown]
# **🧑‍💼 Best Location Listings for Hosts**

# %%
best_hosts = df_filtered.sort_values(by=['price', 'number_of_reviews'], ascending=False).head(10)
print("Best Listings for Hosts:\n")
print(best_hosts[['name', 'host_name', 'neighbourhood_group', 'price', 'number_of_reviews']])
# Out:
# Best Listings for Hosts:
#
#                                                     name     host_name  \
# 19019     Luxury 4br 2ba, sleeps 12! Blocks from Subway.         David
# 19108            Bright Luxe Williamsburg Home - 4br 2ba          Todd
# 20067    Sonder | Stock Exchange | Tranquil 2BR + Lounge  Sonder (NYC)
# 18850  Immaculate Central West Village 1BR, Gym, Door...    Blueground
# 134                               Cottage in the Village        Olivia
# 10079  TOWNHOUSE  (Backyard/Rooftop + Photoshoots/Eve...      Benjamin
# 1691                       2000 sqf  Duplex in Townhouse     Francesca
# 16051      Great 2 bedroom apartment in midtown for 5ppl         Ramon
# 7625            Tranquility in Park Slope House & Garden        Daniel
# 2907              Beautiful apartment by Columbus Circle        Andrew
#
#       neighbourhood_group  price  number_of_reviews
# 19019            Brooklyn    392                 19
# 19108            Brooklyn    392                 18
# ...

# %% [markdown]
# **📈 Price Variations Across Neighborhood Groups**

# %%
sns.boxplot(data=df_filtered, x='neighbourhood_group', y='price', palette='coolwarm')
plt.title('Price Variation by Neighborhood Group')
plt.show()

# %% [markdown]
# **Key Insights:-**
# - Manhattan shows the highest median price and the widest range of prices, including several outliers. This suggests it hosts both luxury and budget options, but leans toward the high end.
# - Brooklyn comes next, with moderately high prices and a slightly narrower spread—indicating more pricing consistency among its listings.
# - Queens and Bronx have significantly lower median prices. Their box plots are compact, suggesting relatively affordable listings with fewer extremes.
# - Staten Island, while having the lowest overall prices, shows noticeable outlier spikes. This implies that most listings are budget-friendly, but a few may offer premium accommodations.

# %% [markdown]
# **📊 Average Reviews Per Month by Room Type**

# %%
avg_reviews = df_filtered.groupby('room_type')['reviews_per_month'].mean().sort_values()
print("Average Reviews Per Month by Room Type:\n", avg_reviews)
# Out:
# Average Reviews Per Month by Room Type:
#  room_type
# Entire home/apt    1.059386
# Shared room        1.136277
# Private room       1.169428
# Name: reviews_per_month, dtype: float64

# %% [markdown]
# **🔄 Correlation Between Price and Reviews**

# %%
sns.scatterplot(data=df_filtered, x='number_of_reviews', y='price', hue='neighbourhood_group', palette='tab10')
plt.title('Price vs Number of Reviews')
plt.show()

# %% [markdown]
# **Key Observation:-**
# - Most listings cluster toward the lower price range (₹0–₹150) and have moderate review counts, showing a concentration of affordable, well-reviewed options.
# - Listings in Manhattan and Brooklyn are more frequent across the entire price spectrum, with Manhattan appearing in the higher price range more often.
# - Listings with very high prices (₹300–₹400) tend to receive fewer reviews, suggesting that premium accommodations cater to a smaller audience or may be booked less frequently.
# - Staten Island and the Bronx show fewer listings overall and are mostly confined to the lower price band with limited review volume.

# %% [markdown]
# **💵 Most Affordable Neighborhoods (Average Price < 100)**

# %%
affordable = df_filtered.groupby('neighbourhood')['price'].mean()
affordable_neighs = affordable[affordable < 100].sort_values()
print("Affordable Neighborhoods:\n", affordable_neighs)
# Out:
# Affordable Neighborhoods:
#  neighbourhood
# Bull's Head      47.333333
# Hunts Point      50.500000
# Tremont          51.545455
# Soundview        53.466667
# New Dorp         57.000000
#                    ...
# Sunset Park      95.939474
# Astoria          96.295918
# St. George       99.382979
# Fresh Meadows    99.500000
# Crown Heights    99.764126
# Name: price, Length: 136, dtype: float64

# %% [markdown]
# **🚫 Listings with Zero Reviews**

# %%
zero_reviews = df_filtered[df_filtered['number_of_reviews'] == 0]
print("Listings with Zero Reviews:\n", zero_reviews[['name', 'neighbourhood', 'price']].head())
# Out:
# Listings with Zero Reviews:
#                                     name    neighbourhood  price
# 10    Huge 2 BR Upper East  Cental Park      East Harlem    190
# 135        Prime East Village 1 Bedroom     East Village    200
# 183  LARGE 1BR (CONV 2BR) CROWN HEIGHTS    Crown Heights    100
# 235       Parisian apartment in Chelsea          Chelsea    200
# 241  Your own apartment off Park Avenue  Upper East Side    250

# %% [markdown]
# **⏳ Distribution of Minimum Nights by Room Type**

# %%
sns.boxplot(data=df_filtered, x='room_type', y='minimum_nights', palette='Accent')
plt.title('Minimum Nights by Room Type')
plt.show()

# %% [markdown]
# **Observations:-**
# - Entire home/apt listings show the widest range, with several extreme outliers going as high as 1200+ nights. This may reflect long-term rental strategies or misconfigured listings.
# - Private rooms cluster tightly around shorter stay requirements, usually between 1 and 10 nights, making them ideal for short-term or budget-conscious travelers.
# - Shared rooms, though fewer in number, tend to require very few minimum nights, with a narrow and consistent distribution suggesting standardized stay policies.

# %% [markdown]
# **🔝 Top 10 Reviewed Listings**

# %%
top_reviewed = df_filtered.sort_values('number_of_reviews', ascending=False).head(10)
print("Top 10 Reviewed Listings:\n", top_reviewed[['name', 'price', 'number_of_reviews']])
# Out:
# Top 10 Reviewed Listings:
#                                                      name  price  \
# 28116                            Room near JFK Queen Bed     47
# 24273                         Great Bedroom in Manhattan     49
# 24272                     Beautiful Bedroom in Manhattan     49
# 24269                       Private Bedroom in Manhattan     49
# 28808                            Room Near JFK Twin Beds     47
# 27636                  Steps away from Laguardia airport     46
# 24220           Manhattan Lux Loft.Like.Love.Lots.Look !     99
# 31857  Cozy Room Family Home LGA Airport NO CLEANING FEE     48
# 2726                  Private brownstone studio Brooklyn    160
# 23718                    LG Private Room/Family Friendly     60
#
#        number_of_reviews
# 28116                629
# 24273                607
# 24272                597
# 24269                594
# 28808                576
# 27636                543
# 24220                540
# ...

# %% [markdown]
# **📉 Price vs Reviews per Month by Neighborhood Group**

# %%
sns.scatterplot(data=df_filtered, x='reviews_per_month', y='price', hue='neighbourhood_group', style='room_type')
plt.title('Reviews Per Month vs Price by Group')
plt.show()

# %% [markdown]
# **🧮 Listings Count by Host Name (Top 10 Only)**

# %%
top_hosts_df = df_filtered['host_name'].value_counts().head(10)
sns.barplot(x=top_hosts_df.values, y=top_hosts_df.index, palette='magma')
plt.title('Top Hosts by Listings Count')
plt.xlabel('Number of Listings')
plt.show()

# %% [markdown]
# # **Feature Engineering**

# %% [markdown]
# **Useful for comparing budget listings vs premium ones**

# %%
# Bucket pricing
df_filtered['price_range'] = pd.cut(df['price'], bins=[0, 100, 300, 500, 1000], labels=['Luxury', 'Premium', 'Moderate', 'Budget'])

# %% [markdown]
# - Budget listings (₹0–₹100) dominate the dataset, a strong market for affordable stays.
# - Moderate and Premium categories (₹100–₹500) are well-represented, catering to middle-range travelers.
# - Luxury listings (₹500–₹1000) are less common, indicating that high-end options are limited or niche.

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0     Private room    149               1                  9
# ...

# %% [markdown]
# # **Business Conclusion**
# This exploratory data analysis reveals valuable insights into how Airbnb operates across New York City’s boroughs and listing types. By examining patterns in pricing, room availability, reviews, and host activity, we can draw several strategic conclusions:
# - 🔹 Market Concentration: Manhattan and Brooklyn dominate the Airbnb landscape in both listing volume and guest engagement, reflecting high tourist demand and host competitiveness.
# - 🔹 Affordability Drives Engagement: Listings in the lower price range (₹50–₹150) receive significantly more reviews and bookings, confirming that budget-friendly accommodations are key to high occupancy and performance.
# - 🔹 Room Type Preferences: Entire homes are popular for premium stays, while private rooms dominate short, affordable bookings—highlighting diverse traveler preferences and segmentation opportunities.
# - 🔹 Review Activity as Performance Metric: Features like reviews_per_month and number_of_reviews act as reliable indicators of guest satisfaction and listing popularity, aiding platform ranking and host decision-making.
# - 🔹 Geographic Gaps & Growth Potential: Boroughs like Staten Island and the Bronx are underrepresented but show isolated demand opportunities. Airbnb could incentivize listings and promote unique local experiences in these areas.
# - 🔹 Host Behavior Trends: Hosts with multiple listings often vary pricing and minimum night rules. Standardizing these strategies may optimize guest experience while simplifying operations.
